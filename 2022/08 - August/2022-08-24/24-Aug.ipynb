# %% [markdown]
# - By *increasing the amount of data* in solution matrix,  the update becomes **less effective**.
#     - <strong>FALSE: increasing the snapshots, decomposes the solution into higher modes. So when applying the update we should include more modes in the update (When we increase the number of snapshots, we should increase the rank of SVD approximation as well)</strong>
# - Maybe the dominant modes have short cycles that happen inside 10 cycles, so by just fetching 10 steps, we can estimate them accurately. <strong>(FALSE)</strong>

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pandas as pd

# %%
fig = plt.figure(figsize=(15,3), dpi=150)
plt.tight_layout()

rows = 1; cols = 2

fig.add_subplot(rows, cols, 1)
image1 = mpimg.imread('./dmd_it500_diffSnaps.png')
ax = plt.imshow(image1)
plt.axis('off')
plt.title('rank 2')

fig.add_subplot(rows, cols, 2)
image1 = mpimg.imread('./dmd_diffSnaps_rnk4.png')
plt.imshow(image1)
plt.axis('off')
plt.title('rank 4')

plt.show()
