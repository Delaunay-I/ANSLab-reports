# %% [markdown]
# - By *increasing the amount of data* in solution matrix,  the update becomes **less effective**.
# - Maybe the dominant modes have short cycles that happen inside 10 cycles, so by just fetching 10 steps, we can estimate them accurately.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pandas as pd

# %%
fig = plt.figure(figsize=(15,3), dpi=150)
plt.tight_layout()

rows = 1; cols = 2

fig.add_subplot(rows, cols, 1)
image1 = mpimg.imread('./dmd_it500_diffSnaps.png')
ax = plt.imshow(image1)
plt.axis('off')
plt.title('rank 2')

fig.add_subplot(rows, cols, 2)
image1 = mpimg.imread('./dmd_diffSnaps_rnk4.png')
plt.imshow(image1)
plt.axis('off')
plt.title('rank 4')

plt.show()
