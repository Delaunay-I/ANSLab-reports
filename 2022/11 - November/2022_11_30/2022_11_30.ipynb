# %% [markdown]
# # Nov 30th, 2022

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import Image, HTML, display

# %% [markdown]
# ## 1. Found a case where a low correlated DMD update worked great
# Correlated updates is not what defines a good update. So, when we have a update and DMD update with correlation of 0.98, the update might not be considered a good update. look at the figure below.

# %%
display(HTML("<table><tr><td><img src='NS-STR-800-1500.png' width=650></td><td><img src='NS-STR-800-1modeupdate.png' width=700></td></tr></table>"))
# Out:
# <table><tr><td><img src='NS-STR-800-1500.png' width=650></td><td><img src='NS-STR-800-1modeupdate.png' width=700></td></tr></table>

# %%
Image("NS-STR-solution1Dplots.png")

# %% [markdown]
# As we can see constructing an update with only one mode is highly corelated with the previosly applied update, but it would result in an increase in the solution norm.

# %% [markdown]
# ## 2. Fixed the function for computing DMD modes in C++, using Eigen3 library

# %% [markdown]
# Although the modes are not the same as the ones in Python.
# Because the complex eigenvectors are different.
# As a result, the inner product of DMD modes with solution updates are not the same.
# How could we encounter this issue?
