# %% [markdown]
# We got bunch of eigenvalues that are close in amplitude
#
# We got a few around -167, -246, -640, ...

# %% [markdown]
# | Real(\lambda) | Imag | Accuracy |
# | :- | -: | :-: |
# | -98.6833870504 | 0.00708188481171 |
# | -98.6833870504 | -0.00708188481171 |

# %% [markdown]
# ## On the left we have two close eigenvalues, and on the right we have the 400 rightmost eigenvalues.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

fig = plt.figure(figsize=(100, 100))
rows = 1
cols = 2
ax = fig.add_subplot(rows, cols,1)

img1 = mpimg.imread('./eig1.png')
img2 = mpimg.imread('./allEigs.png')

plt.imshow(img1)

fig.add_subplot(rows, cols, 2)
plt.imshow(img2)

# %% [markdown]
# ## Here are all the converged eigenvalues (4082 eigenvalues converged amongst all which is 6266)

# %%
img_allEigs = mpimg.imread('./allEigs_4082.png')
fig = plt.figure(figsize=(100, 100))

plt.imshow(img_allEigs)
